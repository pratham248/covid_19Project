# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_json("https://www.mohfw.gov.in/data/datanew.json")
df.head()
# Out:
#    sno                   state_name  active  positive    cured  death  \
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129
# 1    2               Andhra Pradesh       0   2340676  2325943  14733
# 2    3            Arunachal Pradesh       0     67049    66753    296
# 3    4                        Assam       0    746150   738115   8035
# 4    5                        Bihar       1    855262   842947  12314
#
#    new_active  new_positive  new_cured  new_death death_reconsille total  \
# 0           0         10766      10637        129
# 1           0       2340676    2325943      14733
# 2           0         67049      66753        296
# 3           0        746150     738115       8035
# 4           1        855262     842947      12314
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df.describe()
# Out:
#              sno       active      positive         cured          death  \
# count  37.000000    37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    78.378378  2.432307e+06  2.403407e+06   28752.540541
# std    10.824355   285.728829  7.418824e+06  7.329747e+06   89152.733752
# min     1.000000     0.000000  1.076600e+04  1.063700e+04       4.000000
# 25%    10.000000     0.000000  1.084730e+05  1.075290e+05    1185.000000
# 50%    19.000000     1.000000  7.461500e+05  7.381150e+05    7768.000000
# 75%    28.000000     9.000000  1.348390e+06  1.339114e+06   14733.000000
# max    37.000000  1450.000000  4.499767e+07  4.446302e+07  531922.000000
#
#         new_active  new_positive     new_cured      new_death  state_code  \
# count    37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     77.621622  2.432308e+06  2.403409e+06   28752.648649   18.324324
# std     283.700091  7.418830e+06  7.329755e+06   89153.059188   11.212726
# min       0.000000  1.076600e+04  1.063700e+04       4.000000    0.000000
# 25%       0.000000  1.084770e+05  1.075290e+05    1185.000000    9.000000
# 50%       1.000000  7.461500e+05  7.381150e+05    7768.000000   18.000000
# 75%       8.000000  1.348393e+06  1.339115e+06   14733.000000   28.000000
# max    1436.000000  4.499771e+07  4.446307e+07  531924.000000   37.000000
#
#        actualdeath24hrs
# count         37.000000
# mean           0.108108
# std            0.393262
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            2.000000

# %%
data_active=df.sort_values(["active"],ascending=False)
data_active=data_active.iloc[:7,:]
data_active
# Out:
#     sno        state_name  active  positive     cured   death  new_active  \
# 36   37                      1450  44997673  44463021  531922        1436
# 16   17         Kerala***    1007   6907158   6834205   71946        1005
# 35   36       West Bengal     193   2125988   2104241   21554         192
# 20   21       Maharashtra      88   8170364   8021719  148557          83
# 34   35     Uttar Pradesh      60   2145416   2121649   23707          58
# 11   12           Haryana      26   1078890   1068109   10755          26
# 12   13  Himachal Pradesh      11    322884    318632    4241          10
#
#     new_positive  new_cured  new_death death_reconsille total  state_code  \
# 36      44997706   44463066     531924                      2           0
# 16       6907160    6834208      71947                      1          32
# 35       2125996    2104250      21554                                 19
# 20       8170373    8021733     148557                                 27
# 34       2145416    2121650      23708                      1           9
# 11       1078890    1068109      10755                                  6
# 12        322885     318634       4241                                  2
#
#     actualdeath24hrs
# 36                 2
# 16                 1
# 35                 0
# 20                 0
# 34                 1
# 11                 0
# 12                 0

# %%
explode = [0.1,0,0,0,0,0,0]
colors = ["r","b",'y','g','c','m','brown']
textprops = {"fontsize":8}
wedgeprops = {"linewidth":1, "width":1, "edgecolor":"black"}
fontdict = {"fontsize":10}
plt.title("top seven corona affected states \n Total Active cases in India: {} \n Total active cases in these states: {}%".format(sum(df['active']), round(sum(data_active['active']),sum(df['active'], 4)*100), fontdict = fontdict))
plt.pie(data_active['active'], labels=data_active['state_name'], explode=explode, colors=colors, autopct="%0.2f", radius=1, wedgeprops=wedgeprops, textprops=textprops, pctdistance=0.6, labeldistance=1.1, rotatelabels=True)
plt.legend(loc=0)
plt.show()

# %%
explode = [0.05,0,0,0,0,0,0]
colors = ["r","b","y", "g", "c","m","brown"]
textprops = {"fontsize":8}
wedgeprops = {"linewidth":1, "width":1,"edgecolor":"black"}
plt.figure(figsize=(16,9))
fontdict = {"fontsize":10}
plt.title("Top seven corrona affected states \n Total active cases in india  : {} \n Total active cases in these states {} \n Total percentage of active cases in these states :  {}%".format(sum(df["active"]) ,
        sum(data_active["active"])  , round(sum(data_active["active"]) / sum(df["active"])  , 4)* 100 ), fontdict = fontdict)
plt.pie(data_active["active"], labels = data_active["state_name"],explode = explode,colors = colors, autopct= "%0.2f%%",radius = 1,
        wedgeprops = wedgeprops , textprops = textprops, pctdistance = 0.6,labeldistance = 1.1 , rotatelabels=True )
plt.legend(loc = 0)
plt.show()

# %%
def top_seven_states_index(x):
    positive=list(x)
    top_seven_states=[]
    index_active=[]
    state_active=[]
    for i in range(7):
        top_seven_states.append(max(positive))
        positive.remove(max(positive))
    
    for i in range(len(x)):
        for j in range(len (top_seven_states)):
            if x[i]==top_seven_states[j]:
                index_active.append(i)
                
    for i in index_active:
        state_active.append(df['state_name'][i])
        
    for i in index_active:
        top_seven_states.append(x[i])
        
    return top_seven_states,state_active,index_active

# %%
top_seven_states,states_name,index_active = top_seven_states_index(df["active"])
